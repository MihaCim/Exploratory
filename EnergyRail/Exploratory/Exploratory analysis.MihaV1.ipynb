# %% [markdown]
# ## Markup syntax

# %% [markdown]
# ## Libraties and data source

# %%
# import libraries
import pandas as pd
import numpy as np
import datetime as dt
import time as tm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Frame

# %%
dataDir = (r"C:/Users/Cimperman/Desktop/Programming/test1/")
df = pd.read_csv(dataDir + r"zigbee2.csv", parse_dates = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-2d249ca59bcb> in <module>()
#       1 dataDir = (r"C:/Users/Cimperman/Desktop/Programming/test1/")
# ----> 2 df = pd.read_csv(dataDir + r"zigbee2.csv", parse_dates = True)
#
# ...

# %%
# Data is loaded in df. dataDir tell us folder of file.


#dataDir = ""C:/Users/Cimperman/Desktop/Programming/test1/""
#dataDir = "C:\Users\miha\Desktop\Programming\test1\"
dataDir = "C:/Users/Cimperman/Desktop/Programming/test1/"
df = pd.read_csv(dataDir + "zigbee2.csv", parse_dates = True)
#df = pd.read_csv(dataDir + ""zigbee2.csv"")

# Converting epoch 'Timestamp' to date&time.
def date (x):
    x=dt.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S')
    return x
df['Timestamp']=df['Timestamp'].apply(date)

#printout
df.head()
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-3343d2e4a0fa> in <module>()
#       5 #dataDir = "C:\Users\miha\Desktop\Programming\test1\"
#       6 dataDir = "C:/Users/Cimperman/Desktop/Programming/test1/"
# ----> 7 df = pd.read_csv(dataDir + "zigbee2.csv", parse_dates = True)
#       8 #df = pd.read_csv(dataDir + ""zigbee2.csv"")
#       9
#
# ...

# %% [markdown]
# ## Data transformation

# %%
#df.describe()
#df["HourOfDay"] = df.index.hour # Could try cyclic hours
#df["DayOfWeek"] = df.index.dayofweek
#df["Month"] = df.index.month # month of year [1-12]
#df["Weekday"] = df.DayOfWeek.apply(lambda x: 1 if x < 5 else 0)
#df["Weekend"] = df.DayOfWeek.apply(lambda x: 0 if x < 5 else 1)

#df['2017-11-27 08:07:54':'2017-12-12 13:34:32'][['HourOfDay','DayOfWeek','Month','Weekday','BusinessDay']]
#temp1 = ch0 * ch1
#tem1
df.Colums = [P]
df

# %% [markdown]
# ## Plots

# %%
_ = df[["ch0","ch1"]].plot(subplots=True, layout=(3,1), style=['b','b','b'], 
                                                       figsize=(20,20), x_compat=True, sharex=False)

# %%
#hourly chart
a = 20000
b = a + 3600
df[a:b][["ch0"]].plot(layout=(3,1), figsize=(20,5), x_compat=True, sharex=False)

# %%
#daily chart
a = 820000
b = a + 86400
df[a:b][["ch0"]].plot(layout=(3,1), figsize=(20,5), x_compat=True, sharex=False)

# %%
#weekly chart
a = 604800
b = a + 604800
df[a:b][["ch0"]].plot(layout=(3,1), figsize=(20,5), x_compat=True, sharex=False)

# %%
df.plot(x='timestamp', y='ch1')

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ## Feature engineering

# %%
# Tranformacija med podatki in vektorjem za model feeding-
# Feature evaluation

# %% [markdown]
# ## Model  training
